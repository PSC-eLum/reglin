# %%
import math
import pandas as pd
#import datetime

# %%
df = pd.read_csv("DonneesMeteo.txt",delim_whitespace=True, low_memory=False, skiprows=1)

# %%
df['hh(UTC)']
# Out:
# 0         6.0167
# 1         6.0333
# 2         6.0500
# 3         6.0667
# 4         6.0833
# 5         6.1000
# 6         6.1167
# 7         6.1333
# 8         6.1500
# 9         6.1667
# 10        6.1833
# 11        6.2000
# 12        6.2167
# 13        6.2333
# 14        6.2500
# 15        6.2667
# 16        6.2833
# 17        6.3000
# 18        6.3167
# 19        6.3333
# 20        6.3500
# 21        6.3667
# 22        6.3833
# 23        6.4000
# 24        6.4167
# 25        6.4333
# 26        6.4500
# 27        6.4667
# 28        6.4833
# 29        6.5000
#           ...
# 49859    18.5000
# 49860    18.5167
# 49861    18.5333
# 49862    18.5500
# 49863    18.5667
# 49864    18.5833
# 49865    18.6000
# 49866    18.6167
# 49867    18.6333
# 49868    18.6500
# 49869    18.6667
# 49870    18.6833
# 49871    18.7000
# 49872    18.7167
# 49873    18.7333
# 49874    18.7500
# 49875    18.7667
# 49876    18.7833
# 49877    18.8000
# 49878    18.8167
# 49879    18.8333
# 49880    18.8500
# 49881    18.8667
# 49882    18.8833
# 49883    18.9000
# 49884    18.9167
# 49885    18.9333
# 49886    18.9500
# 49887    18.9667
# 49888    18.9833
# Name: hh(UTC), dtype: float64

# %%
df['hh(UTC)']*3600
#+ pd.to_datetime(df['Date'], format="%Y%m%d")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\Jean\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     468             result = expressions.evaluate(op, str_rep, x, y,
# --> 469                                           raise_on_error=True, **eval_kwargs)
#     470         except TypeError:
#
# C:\Users\Jean\Anaconda3\lib\site-packages\pandas\computation\expressions.py in evaluate(op, op_str, a, b, raise_on_error, use_numexpr, **eval_kwargs)
#     217         return _evaluate(op, op_str, a, b, raise_on_error=raise_on_error,
# --> 218                          **eval_kwargs)
#     219     return _evaluate_standard(op, op_str, a, b, raise_on_error=raise_on_error)
#
# C:\Users\Jean\Anaconda3\lib\site-packages\pandas\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, raise_on_error, truediv, reversed, **eval_kwargs)
#     128     if result is None:
# --> 129         result = _evaluate_standard(op, op_str, a, b, raise_on_error)
#     130
#
# C:\Users\Jean\Anaconda3\lib\site-packages\pandas\computation\expressions.py in _evaluate_standard(op, op_str, a, b, raise_on_error, **eval_kwargs)
#      70         _store_test_result(False)
# ---> 71     return op(a, b)
#      72
#
# TypeError: ufunc add cannot use operands with types dtype('float64') and dtype('<M8[ns]')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-d801ce398a32> in <module>()
# ----> 1 df['hh(UTC)']*3600 + pd.to_datetime(df['Date'], format="%Y%m%d")
#       2
#       3 #time.append(row[1]*3600 + pd.to_datetime(row[0], format="%Y%m%d"))
#       4 #time = pd.to_datetime(df['Date'], format="%Y%m%d")
#       5 #df['Date'] =
#
# C:\Users\Jean\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right, name)
#     522                     rvalues = com.take_1d(rvalues, ridx)
#     523
# --> 524             arr = na_op(lvalues, rvalues)
#     525
#     526             return left._constructor(wrap_results(arr), index=index,
#
# C:\Users\Jean\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     473                 result = np.empty(x.size, dtype=dtype)
#     474                 mask = notnull(x) & notnull(y)
# --> 475                 result[mask] = op(x[mask], _values_from_object(y[mask]))
#     476             elif isinstance(x, np.ndarray):
#     477                 result = np.empty(len(x), dtype=x.dtype)
#
# TypeError: ufunc add cannot use operands with types dtype('float64') and dtype('<M8[ns]')

# %%
df.corr()
# Out:
#                   Date   hh(UTC)     P1(W)    Tp1(C)     P2(W)    Tp2(C)  \
# Date          1.000000 -0.028359 -0.000769  0.147691 -0.252408 -0.129917
# hh(UTC)      -0.028359  1.000000  0.047357  0.223339  0.058608  0.255820
# P1(W)        -0.000769  0.047357  1.000000  0.846722  0.938890  0.862549
# Tp1(C)        0.147691  0.223339  0.846722  1.000000  0.858361  0.995192
# P2(W)        -0.252408  0.058608  0.938890  0.858361  1.000000  0.848474
# Tp2(C)       -0.129917  0.255820  0.862549  0.995192  0.848474  1.000000
# IrrPOA(W/m2)  0.025878  0.067896  0.978788  0.877854  0.946334  0.887659
# Gz2(W/m2)     0.093394  0.045422  0.928291  0.872613  0.915923  0.883025
# Drz2(W/m2)   -0.008153  0.006138  0.718077  0.671719  0.786875  0.729954
# Dfz2(W/m2)    0.115045  0.060441  0.493030  0.464919  0.508598  0.501966
# IRz2(W/m2)    0.371783  0.192334 -0.317713 -0.111635 -0.504020 -0.310071
# T(C)          0.455009  0.435229  0.394982  0.713965  0.357922  0.697301
# WS(m/s)      -0.031453  0.073771  0.133656 -0.030343 -0.053191 -0.080675
# WD(deg)       0.048329  0.051582 -0.049585 -0.101475 -0.048114 -0.064358
# mpGz1(W/m2)   0.011636  0.073474  0.976945  0.885929  0.958935  0.902477
# IRz1dn(W/m2)  0.430350  0.286800  0.023259  0.259073 -0.233520  0.003680
# IRz1up(W/m2)  0.380225  0.381500  0.671606  0.892321  0.668481  0.899687
# mpT(C)        0.425743  0.441571  0.437464  0.748986  0.424563  0.744747
# mpWS(m/s)     0.047509  0.090461  0.133521  0.021319 -0.070512 -0.029688
# mpWD(deg)    -0.000716 -0.090754  0.074099  0.114087  0.126208  0.113499
# SZA(deg)     -0.207147 -0.083815 -0.667123 -0.666546 -0.541517 -0.586803
# SAA(deg)     -0.009913  0.994093  0.040420  0.219286  0.048640  0.249425
#
#               IrrPOA(W/m2)  Gz2(W/m2)  Drz2(W/m2)  Dfz2(W/m2)    ...     \
# Date              0.025878   0.093394   -0.008153    0.115045    ...
# hh(UTC)           0.067896   0.045422    0.006138    0.060441    ...
# P1(W)             0.978788   0.928291    0.718077    0.493030    ...
# Tp1(C)            0.877854   0.872613    0.671719    0.464919    ...
# P2(W)             0.946334   0.915923    0.786875    0.508598    ...
# Tp2(C)            0.887659   0.883025    0.729954    0.501966    ...
# IrrPOA(W/m2)      1.000000   0.935867    0.742277    0.465443    ...
# Gz2(W/m2)         0.935867   1.000000    0.781350    0.526847    ...
# Drz2(W/m2)        0.742277   0.781350    1.000000   -0.010452    ...
# Dfz2(W/m2)        0.465443   0.526847   -0.010452    1.000000    ...
# IRz2(W/m2)       -0.312442  -0.281170   -0.583781    0.215182    ...
# T(C)              0.445935   0.468827    0.353266    0.286758    ...
# WS(m/s)           0.100728   0.109559   -0.004240    0.164546    ...
# WD(deg)          -0.066355  -0.064745   -0.158350    0.100042    ...
# mpGz1(W/m2)       0.986494   0.943075    0.759469    0.462036    ...
# IRz1dn(W/m2)      0.037813   0.059457   -0.288124    0.357772    ...
# IRz1up(W/m2)      0.714713   0.730942    0.508786    0.438069    ...
# mpT(C)            0.486023   0.504881    0.383618    0.308484    ...
# mpWS(m/s)         0.109376   0.126819   -0.013221    0.193443    ...
# mpWD(deg)         0.089693   0.087186    0.188819   -0.080136    ...
# SZA(deg)         -0.657084  -0.687681   -0.270646   -0.684533    ...
# SAA(deg)          0.062906   0.040583    0.003658    0.052781    ...
#
#                WS(m/s)   WD(deg)  mpGz1(W/m2)  IRz1dn(W/m2)  IRz1up(W/m2)  \
# Date         -0.031453  0.048329     0.011636      0.430350      0.380225
# hh(UTC)       0.073771  0.051582     0.073474      0.286800      0.381500
# P1(W)         0.133656 -0.049585     0.976945      0.023259      0.671606
# Tp1(C)       -0.030343 -0.101475     0.885929      0.259073      0.892321
# P2(W)        -0.053191 -0.048114     0.958935     -0.233520      0.668481
# Tp2(C)       -0.080675 -0.064358     0.902477      0.003680      0.899687
# IrrPOA(W/m2)  0.100728 -0.066355     0.986494      0.037813      0.714713
# Gz2(W/m2)     0.109559 -0.064745     0.943075      0.059457      0.730942
# Drz2(W/m2)   -0.004240 -0.158350     0.759469     -0.288124      0.508786
# Dfz2(W/m2)    0.164546  0.100042     0.462036      0.357772      0.438069
# IRz2(W/m2)    0.098414  0.178721    -0.332038      0.914052      0.119359
# T(C)          0.005384  0.006308     0.445380      0.565431      0.894146
# WS(m/s)       1.000000  0.292665     0.109226      0.123494      0.035452
# WD(deg)       0.292665  1.000000    -0.068143      0.171925     -0.027055
# mpGz1(W/m2)   0.109226 -0.068143     1.000000      0.018750      0.709837
# IRz1dn(W/m2)  0.123494  0.171925     0.018750      1.000000      0.463297
# IRz1up(W/m2)  0.035452 -0.027055     0.709837      0.463297      1.000000
# mpT(C)        0.020070  0.004875     0.481129      0.552369      0.913206
# mpWS(m/s)     0.839607  0.310968     0.117310      0.201652      0.076886
# mpWD(deg)    -0.194839 -0.688897     0.088881     -0.185932      0.044793
# SZA(deg)     -0.186121 -0.022687    -0.651172     -0.445951     -0.605970
# SAA(deg)      0.072350  0.056747     0.069470      0.293613      0.390954
#
#                 mpT(C)  mpWS(m/s)  mpWD(deg)  SZA(deg)  SAA(deg)
# Date          0.425743   0.047509  -0.000716 -0.207147 -0.009913
# hh(UTC)       0.441571   0.090461  -0.090754 -0.083815  0.994093
# P1(W)         0.437464   0.133521   0.074099 -0.667123  0.040420
# Tp1(C)        0.748986   0.021319   0.114087 -0.666546  0.219286
# P2(W)         0.424563  -0.070512   0.126208 -0.541517  0.048640
# Tp2(C)        0.744747  -0.029688   0.113499 -0.586803  0.249425
# IrrPOA(W/m2)  0.486023   0.109376   0.089693 -0.657084  0.062906
# Gz2(W/m2)     0.504881   0.126819   0.087186 -0.687681  0.040583
# Drz2(W/m2)    0.383618  -0.013221   0.188819 -0.270646  0.003658
# Dfz2(W/m2)    0.308484   0.193443  -0.080136 -0.684533  0.052781
# IRz2(W/m2)    0.258283   0.190016  -0.206558 -0.221807  0.199461
# T(C)          0.996747   0.097413   0.008342 -0.391926  0.441898
# WS(m/s)       0.020070   0.839607  -0.194839 -0.186121  0.072350
# WD(deg)       0.004875   0.310968  -0.688897 -0.022687  0.056747
# mpGz1(W/m2)   0.481129   0.117310   0.088881 -0.651172  0.069470
# IRz1dn(W/m2)  0.552369   0.201652  -0.185932 -0.445951  0.293613
# IRz1up(W/m2)  0.913206   0.076886   0.044793 -0.605970  0.390954
# mpT(C)        1.000000   0.078650   0.025184 -0.414428  0.446698
# mpWS(m/s)     0.078650   1.000000  -0.255965 -0.233730  0.089726
# mpWD(deg)     0.025184  -0.255965   1.000000  0.012986 -0.094475
# SZA(deg)     -0.414428  -0.233730   0.012986  1.000000 -0.077764
# SAA(deg)      0.446698   0.089726  -0.094475 -0.077764  1.000000
#
# [22 rows x 22 columns]
